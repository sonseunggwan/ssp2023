# %% [markdown]
# # DEEE725 Speech Signal Processing Lab
# ### 2023 Spring, Kyungpook National University
# ### Instructor: Gil-Jin Jang

# %% [markdown]
# ## Lab 04 Spectral subtraction, Wiener filtering, end point detectoin, voice activity detection
# 2023/04/07

# %% [markdown]
# ----
# ### import packages, define analysis parameters and draw parameters, etc.

# %%
# import necessary pacakages
# strange issue: keep the import order to prevent matplotlib error
#  import matplotlib -> librosa -> pyplot -> librosa.display
import sys
import numpy as np
import matplotlib
import librosa
from matplotlib import pyplot as plt
import librosa.display

#from scipy.io import wavfile
from scipy import signal
from scipy.fft import fftshift

# %% [markdown]
# 신호 분석과 스펙트럼을 그리기 위한 다음의 parameter 들을 정의한다.
# 입력 파일의 sampling frequency 를 이용하여 shift size 를 sample 수로 정의하기 위해 사용된다.
# - `Ts`: shift length in seconds, default 0.01 sec = 10 ms.
# - `Tf`: frame length in seconds, default 0.02 sec = 20 ms

# %%
# parameters for signal analysis
# Fs = 16000  native sampling frequency (wav file 에 정의된 것) 을 사용하면 필요 없음
Ts = 0.01   # 10 ms shift size
Tf = 0.02   # 20 ms frame size

# %% [markdown]
# spectrum 을 그리기 위한 parameters.
# - `cmap_plot`: colormap. default value is `pyplot.cm.bone_r` (최소값 흰색, 최대값 검은색 의 gray scale)

# %%
# parameters for drawing
#cmap_plot = plt.cm.bone # default colormap for spectrogram, gray
cmap_plot = plt.cm.bone_r # default colormap for spectrogram, gray, reversed
#cmap_plot = plt.cm.plasma 
#cmap_plot = plt.cm.inferno
#FIG_SIZE = (15,10)   # obsolete
FIG_SIZE = (8,3)

# %% [markdown]
# ---
# ### 이전 lab 들에서 정의한 함수들

# %%
# returns decibel, with preventing 0 input
# note: input should be X(w) or x[n]
# dB = 20 log_10 (abs(x)) = 10 log_10 ( x^2 ) 
def decibel_sq_safe(x, epsilon=1e-10):
    return 10*np.log10(np.maximum(np.real(x*np.conj(x)),epsilon))

def drawspectrogram2(x, Nf, Ns=None, winname='hamming', minpercentile=80, isdbscale=True, isdraw=True):
    # Short-time Fourier transform with half-overlap 
    # Nf: analysis size
    # Ns: shift size 
    # NFFT: FFT size, power of 2
    if Ns==None: Ns=Nf//2
    num_frames = (len(x)-Nf)//Ns+1  # 마지막 채워지지 않은 프레임은 버린다. 구현에 따라 zero-padding해서 사용 가능
    NFFT = int(2**(np.ceil(np.log2(Nf))))   # Nf보다 크거나 같은 2의 거듭제곱을 NFFT 로 정의
    hNo = NFFT//2+1
    X = np.zeros((hNo,num_frames))
    
    # generate window
    if winname=='rect' or winname=='rectangular':
        win = np.ones(Nf)
    else:   # hamming, hann, etc.
        win = librosa.filters.get_window(winname, Nf, fftbins=True)
        
    # STFT
    for i in range(num_frames):
        y = np.fft.fft(win*x[(i*Ns):(i*Ns+Nf)], n=NFFT)
        y = y[:hNo]
        if isdbscale: y = decibel_sq_safe(y)
        else: y = np.abs(y)
        X[:,i] = y

    if isdraw:
        # 상위 80% 정도만 scale 한다. imshow의 vmin vmax 이용 
        vmax = np.max(X[:])
        vmin = np.percentile(X[:], minpercentile)
        specgram_axis = [0,float(len(x))/float(Fs),0,float(Fs)/2]
        plt.imshow(X, cmap=cmap_plot, aspect='auto', origin='lower', extent=specgram_axis, vmax=vmax, vmin=vmin)
        plt.xlabel('time (seconds)')
        plt.ylabel('frequency (Hz)')
    
    return X

# %% [markdown]
# ---
# ### load speech and noise

# %% [markdown]
# Speech 와 noise 파일을 정의한다.

# %%
speechfile = 'gjang-kdigits0-3.wav'
noisefile  = 'car.wav'

# %% [markdown]
# __load an example windows wav file__
# - `librosa.load()`는 $-1 \sim 1$
# - 읽어들인 sampling frequency $F_s$ 를 이용하여 frame size $N_f$, shift size $N_s$를 계산한다.
# - FFT (fast Fourier transform) 크기는 $N_f$ 보다 크거나 같은 2의 거듭제곱으로 FFT 크기 $N_{FFT}$ 을 정의함
# $$ N_{FFT} = 2^{\lceil \log_{2} N_{f} \rceil} $$

# %%
# load audio files with Librosa
speech, Fs = librosa.load(speechfile, sr=None, mono='True')
noise, _ = librosa.load(noisefile, sr=Fs, mono='True')
# sr: target sampling rate. ‘None’ uses the native sampling rate
# mono = True: convert signal to mono

print(speech,speech.shape)
print(noise,noise.shape)

Ns = int(Fs*Ts)    # shift number of samples
Nf = int(Fs*Tf)    # frame number of samples
NFFT = int(2**(np.ceil(np.log2(Nf))))   # Nf보다 크거나 같은 2의 거듭제곱을 NFFT 로 정의
hNo = NFFT//2+1
print('Fs = %d, Ns = %d, Nf = %d, NFFT = %d, hNo = %d' % (Fs, Ns, Nf, NFFT, hNo))
# Out:
# [-4.7912598e-03 -3.7231445e-03 -3.3569336e-03 ... -3.0517578e-05
#  -8.8500977e-04  8.5449219e-04] (37952,)
# [-0.01342773 -0.0222168  -0.02905273 ... -0.0390625  -0.03930664
#  -0.04086304] (175745,)
# Fs = 16000, Ns = 160, Nf = 320, NFFT = 512, hNo = 257

# %% [markdown]
# __generate noisy speech with various SNRs__

# %%
mixsnrs = np.array([20, 10, 0, -10])
std_s = np.std(speech)
std_n = np.std(noise)
mixedSig = []
for snr in mixsnrs:
    gain = np.power(10, -snr/20)
    print('SNR = %.0f dB, gain = %.2f' % (snr, gain))
    m = speech + noise[:len(speech)]/std_n*std_s*gain
    mixedSig.append(m)
# Out:
# SNR = 20 dB, gain = 0.10
# SNR = 10 dB, gain = 0.32
# SNR = 0 dB, gain = 1.00
# SNR = -10 dB, gain = 3.16

# %%
plt.figure(figsize=FIG_SIZE*np.array([1.5,1.5]))

for m in range(len(mixedSig)):
    plt.subplot(len(mixedSig),2,(m+1)*2-1)
    plt.plot(mixedSig[m])
    plt.title('SNR = %.0f dB' % (mixsnrs[m]))
    plt.subplot(len(mixedSig),2,(m+1)*2)
    drawspectrogram2(mixedSig[m], Nf, Ns, minpercentile=1, isdbscale=True, isdraw=True)

# %% [markdown]
# Noise spectrum estimation
# 1. noise 는 stationary, speech 는 non-stationary 가정
# 2. 처음 0.5~1초는 noise 만 있다고 가정하고 이 구간의 평균 spectral energy ($|\cdot|^2$) 을 추정

# %%
# 20 dB mixed speech 에 대하여 잡음 스펙트럼 추정
Tn = 0.5   # 0~0.5초
Nn = Tn*Fs
nframes = int((Nn-Nf)//Ns+1)
mix = mixedSig[0]
Pnn = np.zeros(hNo)   # n*conj(n)
for n in range(nframes):
    x = mix[(n*Ns):((n+1)*Ns)]
    X = np.fft.fft(x, NFFT)
    aX2 = (X*np.conj(X))
    Pnn += aX2[:hNo].real

Pnn = Pnn/nframes
print(Pnn)
# Out:
# [2.25663487e-01 2.09302351e-01 1.58598898e-01 8.82898734e-02
#  3.52517734e-02 1.69230443e-02 1.49109686e-02 1.10162888e-02
#  6.60815565e-03 5.12367991e-03 4.48159914e-03 4.44227409e-03
#  4.96508857e-03 4.09459336e-03 2.70012899e-03 2.74185130e-03
#  2.81476611e-03 1.80265590e-03 1.25347247e-03 1.48734355e-03
#  1.38311381e-03 1.16279506e-03 1.24230610e-03 1.13704862e-03
#  9.54587425e-04 1.05577360e-03 1.03975308e-03 7.94568183e-04
#  7.10677371e-04 6.95587721e-04 6.00262379e-04 6.35761145e-04
#  7.19928987e-04 6.98166578e-04 8.00694567e-04 1.03042645e-03
#  1.10727815e-03 1.13158942e-03 1.34937267e-03 1.71523383e-03
#  2.10093178e-03 2.35166647e-03 2.35766940e-03 2.35688066e-03
#  2.56935490e-03 2.74627079e-03 2.66751062e-03 2.48889329e-03
#  2.32020719e-03 2.11455461e-03 1.87418257e-03 1.58411234e-03
#  1.27014411e-03 1.07968667e-03 1.00146886e-03 8.72820285e-04
#  7.19869049e-04 6.29947474e-04 5.29033488e-04 4.10111184e-04
#  3.85507384e-04 4.44757554e-04 4.92857436e-04 4.85558099e-04
#  4.18645573e-04 3.67983788e-04 4.09519275e-04 4.60919072e-04
#  4.52696253e-04 4.61566750e-04 4.82375786e-04 4.30236020e-04
#  3.65505974e-04 3.67399070e-04 4.10209577e-04 5.09441298e-04
#  6.30073956e-04 5.97866557e-04 4.30766831e-04 3.64756725e-04
#  4.13339954e-04 4.08611650e-04 3.74006358e-04 3.96653457e-04
#  4.06311665e-04 3.65986644e-04 3.56649906e-04 3.85243980e-04
#  3.75716927e-04 3.20712356e-04 2.84725551e-04 2.94482639e-04
#  2.99337009e-04 2.64396840e-04 2.38160963e-04 2.45643974e-04
#  2.38248716e-04 2.22548615e-04 2.43029322e-04 2.55691297e-04
#  2.33614046e-04 2.43840434e-04 2.70335514e-04 2.24739423e-04
#  1.54820351e-04 1.57920221e-04 1.96811045e-04 2.02934794e-04
#  1.82155035e-04 1.57885135e-04 1.60127096e-04 2.00340600e-04
#  2.20201907e-04 1.94374445e-04 1.83903057e-04 1.96579968e-04
#  1.86694364e-04 1.79997450e-04 2.03562089e-04 2.12092930e-04
#  1.95223858e-04 1.87781359e-04 1.85182396e-04 1.82702964e-04
#  1.89232085e-04 1.73860191e-04 1.37128608e-04 1.40797286e-04
#  1.74664396e-04 1.68662090e-04 1.38050421e-04 1.35632403e-04
#  1.46811564e-04 1.52739361e-04 1.66908308e-04 1.77093181e-04
#  1.68542332e-04 1.64064551e-04 1.75554620e-04 1.86079839e-04
#  1.88693407e-04 1.85121531e-04 1.71568506e-04 1.53267549e-04
#  1.43899733e-04 1.45936075e-04 1.49270937e-04 1.50887941e-04
#  1.59418004e-04 1.67421185e-04 1.55288235e-04 1.38228230e-04
#  1.41243457e-04 1.39685041e-04 1.17943595e-04 1.19500520e-04
#  1.50654435e-04 1.58287079e-04 1.42929587e-04 1.45122866e-04
#  1.54850088e-04 1.53816414e-04 1.48390217e-04 1.27993252e-04
#  1.09509473e-04 1.41078659e-04 1.81742093e-04 1.52268833e-04
#  1.00632046e-04 1.11136518e-04 1.49228945e-04 1.59433103e-04
#  1.55972061e-04 1.48457092e-04 1.36446399e-04 1.40397871e-04
#  1.45758849e-04 1.27410216e-04 1.23470662e-04 1.55566117e-04
#  1.66988549e-04 1.33685524e-04 1.05825207e-04 1.08105984e-04
#  1.19009115e-04 1.27661510e-04 1.33748365e-04 1.29570334e-04
#  1.13123657e-04 9.61958083e-05 9.38149953e-05 1.02281300e-04
#  9.97614894e-05 8.54888500e-05 8.10327213e-05 8.65904002e-05
#  9.07349309e-05 9.83174300e-05 1.02742199e-04 8.84174403e-05
#  7.24189572e-05 7.55558097e-05 8.37824430e-05 8.45298394e-05
#  8.16379632e-05 7.31447541e-05 6.87347508e-05 8.34728882e-05
#  9.54646711e-05 7.99121351e-05 5.77649336e-05 5.08051562e-05
#  4.83900108e-05 4.32308707e-05 3.94346954e-05 3.74298254e-05
#  3.99257244e-05 4.28607205e-05 3.50967825e-05 2.55608394e-05
#  2.75001240e-05 3.04170417e-05 2.84107009e-05 3.03070190e-05
#  3.17224647e-05 2.90562737e-05 3.04445866e-05 2.83827722e-05
#  1.75384609e-05 1.66895214e-05 2.51542977e-05 2.19235710e-05
#  1.56611641e-05 1.97378190e-05 2.03199294e-05 1.72070275e-05
#  2.19468755e-05 2.17981176e-05 1.38341799e-05 1.62790438e-05
#  2.07581574e-05 1.36121937e-05 1.17774573e-05 1.79860835e-05
#  1.52742941e-05 1.28989935e-05 1.91548481e-05 1.74240707e-05
#  1.10834740e-05 1.48802394e-05 1.68101916e-05 1.21338575e-05
#  1.42675008e-05 1.58531124e-05 9.74750345e-06 1.04059266e-05
#  1.47080048e-05]

# %% [markdown]
# ---
# ## Programming assignments: spectral subtraction and Wiener filtering, end point detectoin
#
# 1. 각각의 SNR에 대해서 잡음을 앞의 0.5 초 구간에서 추정하고
# - cutoff frequency 가 linear하게 올라가는 lowpass filter에 대해서 10ms shift, 3ms overlap의 trapezoidal (사다리꼴 overlap-add) 구현

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa

# WAV 파일 불러오기
filename = 'kdigits5-3.wav'  # 파일 경로와 이름 설정
x, sr = librosa.load(filename, sr=None, mono=True)  # WAV 파일 읽기

# SNR 값 설정
SNR_dB = [-10, 0, 10, 20]  # 각각의 SNR 값 (dB) 설정

for snr in SNR_dB:
    # 잡음 생성
    rms_signal = np.sqrt(np.mean(x ** 2))  # 원본 신호의 RMS 에너지 계산
    rms_noise = np.sqrt(rms_signal ** 2 / (10 ** (snr / 10)))  # SNR 값에 따라 RMS 잡음 에너지 계산
    noise = np.random.normal(0, rms_noise, len(x))  # 가우시안 분포를 따르는 잡음 생성
    x_noisy = x + noise  # 원본 신호에 잡음 추가

    # 필터링
    window_length = int(sr * 0.01)  # 창 길이 (10ms)
    hop_length = int(sr * 0.01)  # hop 길이 (10ms)
    overlap_length = int(sr * 0.003)  # 오버랩 길이 (3ms)
    cutoff_freq_start = 0  # 시작 cutoff 주파수 (Hz)
    cutoff_freq_end = sr / 2  # 종료 cutoff 주파수 (Hz)

    # 시간 정보 생성
    t = np.arange(len(x)) / sr

    # 추정된 신호 저장할 배열 초기화
    y = np.zeros(len(x))

    # trapezoidal overlap-add 방식으로 필터링
    for i in range(0, len(x_noisy) - window_length, hop_length):
        # 현재 구간에서의 FFT
        x_windowed = x_noisy[i:i + window_length] * np.hanning(window_length)
        X = np.fft.fft(x_windowed)

        # linear하게 올라가는 lowpass 필터 생성
        cutoff_freq = np.linspace(cutoff_freq_start, cutoff_freq_end, window_length)
        X_filtered = X * (cutoff_freq <= cutoff_freq_end)

        # IFFT
        y_ifft = np.fft.ifft(X_filtered)

        # 오버랩-덧셈 방식으로 출력 신호에 더함
        y[i:i + window_length] += np.real(y_ifft)

    # 오버랩 구간의 출력 신호를 보정
    y /= np.max(np.hanning(window_length))

    # 출력 신호의 길이를 원래 신호와 동일하게 자름
    y = y[:len(x)]

    # 결과를 그래프로 시각화
    plt.figure(figsize=(10, 6))
    plt.plot(t,y, label='Filtered Signal')
    plt.plot(t, x, alpha=0.5, label='Original Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.title(f'Filtered Signal with SNR = {snr}dB')
    plt.legend()
    plt.show()

# %% [markdown]
# .

# %% [markdown]
# ## End of Lab 03
